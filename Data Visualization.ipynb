# %% [markdown]
# # Predict Covid Spread - Data Visualization

# %%
# Imports
import numpy as np
import pandas as pd
import warnings

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from matplotlib.ticker import FuncFormatter
from matplotlib.dates import DateFormatter

warnings.filterwarnings('ignore')

# %%
# Reading in cleaned files
train = pd.read_csv('[Cleaned] Forecasting Data/train.csv', parse_dates=['Date'])
test = pd.read_csv('[Cleaned] Forecasting Data/test.csv', parse_dates=['Date'])

# Tabulating data
data = train.append(test)
group = data.groupby('Date')['Date', 'Confirmed','Deaths', 'Recovered', 'Active'].sum().reset_index()
group = group.set_index('Date')
# Out:
#             Confirmed  Deaths  Recovered   Active
# Date
# 2020-01-22        555      17         28      510
# 2020-01-23        654      18         30      606
# 2020-01-24        941      26         36      879
# 2020-01-25       1434      42         39     1353
# 2020-01-26       2118      56         52     2010
# ...               ...     ...        ...      ...
# 2020-04-19    2404919  168522     608557  1627840
# 2020-04-20    2478258  173965     629862  1674431
# 2020-04-21    2553508  181122     664043  1708343
# 2020-04-22    2630314  187877     693207  1749230
# 2020-04-23    2719327  194727     721689  1802911
#
# [93 rows x 4 columns]

# %%
# Plotting Worldwide Confirmed Case Counts
fig, ax = plt.subplots()
ax.plot(group['Confirmed'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Confirmed Cases')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %%
# Plotting Worldwide Confirmed Case Counts Scaled Logarithmically
fig, ax = plt.subplots()
ax.plot(group['Confirmed'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Confirmed Cases\n(Logarithmic Scale)')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
plt.yscale('log')
plt.show()

# %%
# Plotting Worldwide Deaths Case Counts
fig, ax = plt.subplots()
ax.plot(group['Deaths'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Death Cases')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %%
# Plotting Worldwide Deaths Case Counts Scaled Logarithmically
fig, ax = plt.subplots()
ax.plot(group['Deaths'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Deaths Cases\n(Logarithmic Scale)')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
plt.yscale('log')
plt.show()

# %%
# Plotting Worldwide Recovered Case Counts
fig, ax = plt.subplots()
ax.plot(group['Recovered'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Recovered Cases')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %%
# Plotting Worldwide Recovered Case Counts Scaled Logarithmically
fig, ax = plt.subplots()
ax.plot(group['Recovered'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Recovered Cases\n(Logarithmic Scale)')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
plt.yscale('log')
plt.show()

# %%
# Plotting Worldwide Active Case Counts
fig, ax = plt.subplots()
ax.plot(group['Active'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Active Cases')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
ax.get_yaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
plt.show()

# %%
# Plotting Worldwide Active Case Counts Scaled Logarithmically
fig, ax = plt.subplots()
ax.plot(group['Active'],color='purple')
ax.set(xlabel='Date', ylabel='Case Counts',
       title='Worldwide Active Cases\n(Logarithmic Scale)')
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=2))
ax.xaxis.set_major_formatter(DateFormatter("%m-%d"))
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = 30, ha = 'right')
plt.yscale('log')
plt.show()
